# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install --upgrade gspread gspread_dataframe

# %%
import pandas as pd

# %%
link_data = '/content/drive/MyDrive/IE304/craw_dataset/Dataset.csv'
data = pd.read_csv(link_data)
data.head ()
# Out:
#   Label                                            Comment
# 0   NaN                     Nhỏ không học lớn làm content?
# 1   NaN  Không biết các Sếp bên thethao247 có kiểm tra ...
# 2   NaN  Có thể đằng ấy muốn nói Arsenal chưa có danh h...
# 3   NaN  Là một trang báo chính thống, là một trong nhữ...
# 4   NaN  Tôi hy vọng bài viết này đại diện cho những fa...

# %%
num_rows = len(data)
print("count: ", num_rows)
# Out:
# count:  10196

# %%
data = data.drop(columns=['Label'])
data.insert(0, 'Id', range(1, len(data) + 1))

data.head()
# Out:
#    Id                                            Comment
# 0   1                     Nhỏ không học lớn làm content?
# 1   2  Không biết các Sếp bên thethao247 có kiểm tra ...
# 2   3  Có thể đằng ấy muốn nói Arsenal chưa có danh h...
# 3   4  Là một trang báo chính thống, là một trong nhữ...
# 4   5  Tôi hy vọng bài viết này đại diện cho những fa...

# %%
import gspread
from google.colab import auth
from google.auth import default
from gspread_dataframe import set_with_dataframe

# Xác thực
auth.authenticate_user()
creds, _ = default()

# Kết nối đến Google Sheets
gc = gspread.authorize(creds)

# %%
folder_id = '13Z6G6HRz0sjVy02UKjCwhrDgvfGnQdqw'

test_sheet_key = '1ouophbdjsmMoWvlJDH6giWD7KHRCbiw77AmNktVwHcg'
test_sheet = gc.open_by_key(test_sheet_key)

final_sheet_key = '1soYxw4GYX4Ftnlesv_deUtq7TS2f1KnX8ko0ICeW03U'
final_sheet = gc.open_by_key(final_sheet_key)

# %%
subset_data = data.head(300).reset_index(drop=True)
subset_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-3d3f23e5a29f> in <cell line: 0>()
# ----> 1 subset_data = data.head(300).reset_index(drop=True)
#       2 subset_data.head()
#
# NameError: name 'data' is not defined

# %%
worksheet = test_sheet.get_worksheet(0)
set_with_dataframe(worksheet, subset_data, row=1, col=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9e8e91d62ae5> in <cell line: 0>()
# ----> 1 worksheet = test_sheet.get_worksheet(0)
#       2 set_with_dataframe(worksheet, subset_data, row=1, col=1)
#
# NameError: name 'test_sheet' is not defined

# %%
data_even = data[data['Id'] % 2 == 0]
data_odd = data[data['Id'] % 2 != 0]

data_even.head()
data_odd.head()
# Out:
#    Id                                            Comment
# 1   2  Không biết các Sếp bên thethao247 có kiểm tra ...
# 3   4  Là một trang báo chính thống, là một trong nhữ...
# 5   6  Có thể bạn chỉ muốn tạo tương tác nhưng vì nó ...
# 7   8  https://www.facebook.com/photo/?fbid=624784633...
# 9  10  Ếu hiểu sao mình lại thích Tot vô địch hơn là ...

# %%
worksheet1 = final_sheet.get_worksheet(0)
# set_with_dataframe(worksheet1, data_even, row=1, col=1)

worksheet2 = final_sheet.get_worksheet(1)
# set_with_dataframe(worksheet2, data_odd, row=1, col=1)

# %%
values = worksheet1.get_all_values()

df_1 = pd.DataFrame(values[1:], columns=values[0])

final_data_1 = df_1.iloc[:, [0, 1, 5]]

final_data_1.columns = ['Id', 'Comment', 'Label']

final_data_1.head()
# Out:
#    Id                                            Comment Label
# 0   2  Không biết các Sếp bên thethao247 có kiểm tra ...
# 1   4  Là một trang báo chính thống, là một trong nhữ...
# 2   6  Có thể bạn chỉ muốn tạo tương tác nhưng vì nó ...
# 3   8  https://www.facebook.com/photo/?fbid=624784633...
# 4  10  Ếu hiểu sao mình lại thích Tot vô địch hơn là ...

# %%
values = worksheet2.get_all_values()

df_2 = pd.DataFrame(values[1:], columns=values[0])

final_data_2 = df_2.iloc[:, [0, 1, 5]]

final_data_2.columns = ['Id', 'Comment', 'Label']

final_data_2.head()
# Out:
#   Id                                            Comment Label
# 0  1                     Nhỏ không học lớn làm content?     0
# 1  3  Có thể đằng ấy muốn nói Arsenal chưa có danh h...     0
# 2  5  Tôi hy vọng bài viết này đại diện cho những fa...     0
# 3  7        Cho những ai chưa biết lịch sử của Arsenal!     0
# 4  9  London ra châu âu thì pháo còn kém chel vs tot...     0

# %%
final_data = pd.concat([final_data_1, final_data_2], ignore_index=True)

final_data['Id'] = final_data['Id'].astype(int)
final_data = final_data.sort_values(by='Id').reset_index(drop=True)

final_data.head()
# Out:
#    Id                                            Comment Label
# 0   1                     Nhỏ không học lớn làm content?
# 1   2  Không biết các Sếp bên thethao247 có kiểm tra ...
# 2   3  Có thể đằng ấy muốn nói Arsenal chưa có danh h...
# 3   4  Là một trang báo chính thống, là một trong nhữ...
# 4   5  Tôi hy vọng bài viết này đại diện cho những fa...

# %%
data = worksheet2.get('A:G')

header = data[0]
print(header)
rows = data[1:]

df = pd.DataFrame(rows, columns=header)

# numeric_cols = ['Id', 'Khoa', 'Hoàng', 'Final']
# for col in numeric_cols:
#     if col in df.columns:
#         df[col] = pd.to_numeric(df[col], errors='coerce')
# Out:
# ['Id', 'Comment', 'Xóa', 'Khoa', 'Hoàng', 'Final']

# %%
print(df.head())
print(df.shape[0])
# Out:
#   Id                                            Comment Xóa Khoa Hoàng Final
# 0  1                     Nhỏ không học lớn làm content?        0     0     0
# 1  3  Có thể đằng ấy muốn nói Arsenal chưa có danh h...        0     0     0
# 2  5  Tôi hy vọng bài viết này đại diện cho những fa...        0     0     0
# 3  7        Cho những ai chưa biết lịch sử của Arsenal!        0     0     0
# 4  9  London ra châu âu thì pháo còn kém chel vs tot...        0     0     0
# 5098

# %%
df_cleaned = df[df['Xóa'] != 'x']

print(f"Số dòng sau khi xóa: {len(df_cleaned)}")
# Out:
# Số dòng sau khi xóa: 4146

# %%
print("Các giá trị khác nhau trong cột 'Xóa':")
print(df['Xóa'].unique())
# Out:
# Các giá trị khác nhau trong cột 'Xóa':
# ['' 'x' None]

# %%
dataset = df_cleaned[['Id', 'Comment', 'Final']].copy()
dataset.rename(columns={'Final': 'Label'}, inplace=True)

print(dataset.head())
# Out:
#   Id                                            Comment Label
# 0  1                     Nhỏ không học lớn làm content?     0
# 1  3  Có thể đằng ấy muốn nói Arsenal chưa có danh h...     0
# 2  5  Tôi hy vọng bài viết này đại diện cho những fa...     0
# 3  7        Cho những ai chưa biết lịch sử của Arsenal!     0
# 4  9  London ra châu âu thì pháo còn kém chel vs tot...     0

# %%
print(dataset['Label'].unique())
# Out:
# ['0' '1' '2' None]

# %%
dataset = dataset.dropna(subset=['Label'])

print(f"Số dòng sau khi xóa: {len(dataset)}")
# Out:
# Số dòng sau khi xóa: 4112

# %%
dataset.to_csv("dataset.csv", index=False, encoding='utf-8-sig')
